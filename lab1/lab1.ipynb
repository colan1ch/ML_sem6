# %% [markdown]
# # Лабораторная работа №1
# ## Разведочный анализ данных. Исследование и визуализация данных.
#
# **Цель:** изучение различных методов визуализации данных.
#
# **Датасет:** Wine (Вина) из библиотеки scikit-learn.
#
# ---

# %% [markdown]
# ## 1. Описание набора данных
#
# Датасет **Wine** содержит результаты химического анализа вин, произведённых тремя различными производителями в одном регионе Италии. Каждый образец описывается 13 числовыми признаками:
#
# | № | Признак | Описание |
# |---|---------|----------|
# | 1 | Alcohol | Содержание алкоголя |
# | 2 | Malic acid | Яблочная кислота |
# | 3 | Ash | Зольность |
# | 4 | Alcalinity of ash | Щёлочность золы |
# | 5 | Magnesium | Магний |
# | 6 | Total phenols | Общие фенолы |
# | 7 | Flavanoids | Флавоноиды |
# | 8 | Nonflavanoid phenols | Нефлавоноидные фенолы |
# | 9 | Proanthocyanins | Проантоцианины |
# | 10 | Color intensity | Интенсивность цвета |
# | 11 | Hue | Оттенок |
# | 12 | OD280/OD315 of diluted wines | OD280/OD315 разбавленных вин |
# | 13 | Proline | Пролин |
#
# Целевая переменная — класс вина (0, 1 или 2), определяющий производителя.
# Датасет не содержит пропусков и включает 178 наблюдений.

# %% [markdown]
# ## 2. Импорт библиотек и загрузка данных

# %%
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns
from sklearn.datasets import load_wine

sns.set_theme(style="whitegrid", palette="muted", font_scale=1.1)
plt.rcParams['figure.figsize'] = (10, 6)
plt.rcParams['figure.dpi'] = 100

import warnings
warnings.filterwarnings('ignore')

# %%
wine = load_wine()

df = pd.DataFrame(data=wine.data, columns=wine.feature_names)
df['target'] = wine.target
df['target_name'] = df['target'].map({i: name for i, name in enumerate(wine.target_names)})

df.head(10)
# Out:
#    alcohol  malic_acid   ash  alcalinity_of_ash  magnesium  total_phenols  \
# 0    14.23        1.71  2.43               15.6      127.0           2.80
# 1    13.20        1.78  2.14               11.2      100.0           2.65
# 2    13.16        2.36  2.67               18.6      101.0           2.80
# 3    14.37        1.95  2.50               16.8      113.0           3.85
# 4    13.24        2.59  2.87               21.0      118.0           2.80
# 5    14.20        1.76  2.45               15.2      112.0           3.27
# 6    14.39        1.87  2.45               14.6       96.0           2.50
# 7    14.06        2.15  2.61               17.6      121.0           2.60
# 8    14.83        1.64  2.17               14.0       97.0           2.80
# 9    13.86        1.35  2.27               16.0       98.0           2.98
#
#    flavanoids  nonflavanoid_phenols  proanthocyanins  color_intensity   hue  \
# 0        3.06                  0.28             2.29             5.64  1.04
# 1        2.76                  0.26             1.28             4.38  1.05
# 2        3.24                  0.30             2.81             5.68  1.03
# 3        3.49                  0.24             2.18             7.80  0.86
# 4        2.69                  0.39             1.82             4.32  1.04
# 5        3.39                  0.34             1.97             6.75  1.05
# 6        2.52                  0.30             1.98             5.25  1.02
# 7        2.51                  0.31             1.25             5.05  1.06
# 8        2.98                  0.29             1.98             5.20  1.08
# 9        3.15                  0.22             1.85             7.22  1.01
#
#    od280/od315_of_diluted_wines  proline  target target_name
# 0                          3.92   1065.0       0     class_0
# 1                          3.40   1050.0       0     class_0
# 2                          3.17   1185.0       0     class_0
# 3                          3.45   1480.0       0     class_0
# 4                          2.93    735.0       0     class_0
# 5                          2.85   1450.0       0     class_0
# 6                          3.58   1290.0       0     class_0
# 7                          3.58   1295.0       0     class_0
# 8                          2.85   1045.0       0     class_0
# 9                          3.55   1045.0       0     class_0

# %% [markdown]
# ## 3. Основные характеристики датасета

# %% [markdown]
# ### 3.1. Размерность и типы данных

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 178 entries, 0 to 177
# Data columns (total 15 columns):
#  #   Column                        Non-Null Count  Dtype
# ---  ------                        --------------  -----
#  0   alcohol                       178 non-null    float64
#  1   malic_acid                    178 non-null    float64
#  2   ash                           178 non-null    float64
#  3   alcalinity_of_ash             178 non-null    float64
#  4   magnesium                     178 non-null    float64
#  5   total_phenols                 178 non-null    float64
#  6   flavanoids                    178 non-null    float64
#  7   nonflavanoid_phenols          178 non-null    float64
#  8   proanthocyanins               178 non-null    float64
#  9   color_intensity               178 non-null    float64
#  10  hue                           178 non-null    float64
#  11  od280/od315_of_diluted_wines  178 non-null    float64
#  12  proline                       178 non-null    float64
#  13  target                        178 non-null    int64
#  14  target_name                   178 non-null    object
# dtypes: float64(13), int64(1), object(1)
# memory usage: 21.0+ KB

# %%
df['target_name'].value_counts()
# Out:
# target_name
# class_1    71
# class_0    59
# class_2    48
# Name: count, dtype: int64

# %% [markdown]
# ### 3.2. Описательная статистика

# %%
df.describe().T.style.format("{:.2f}").background_gradient(cmap='YlOrRd', axis=1)
# Out:
# <style type="text/css">
# #T_e76e5_row0_col0, #T_e76e5_row1_col0, #T_e76e5_row2_col0, #T_e76e5_row3_col0, #T_e76e5_row4_col0, #T_e76e5_row5_col0, #T_e76e5_row6_col0, #T_e76e5_row7_col0, #T_e76e5_row8_col0, #T_e76e5_row9_col0, #T_e76e5_row10_col0, #T_e76e5_row11_col0, #T_e76e5_row12_col7, #T_e76e5_row13_col0 {
#   background-color: #800026;
#   color: #f1f1f1;
# }
# #T_e76e5_row0_col1, #T_e76e5_row0_col5, #T_e76e5_row12_col3 {
#   background-color: #fff5b5;
#   color: #000000;
# }
# #T_e76e5_row0_col2, #T_e76e5_row1_col2, #T_e76e5_row1_col3, #T_e76e5_row2_col2, #T_e76e5_row3_col2, #T_e76e5_row4_col2, #T_e76e5_row5_col2, #T_e76e5_row5_col3, #T_e76e5_row6_col2, #T_e76e5_row6_col3, #T_e76e5_row7_col1, #T_e76e5_row7_col2, #T_e76e5_row7_col3, #T_e76e5_row7_col4, #T_e76e5_row7_col5, #T_e76e5_row7_col6, #T_e76e5_row7_col7, #T_e76e5_row8_col2, #T_e76e5_row8_col3, #T_e76e5_row9_col3, #T_e76e5_row10_col2, #T_e76e5_row10_col3, #T_e76e5_row10_col4, #T_e76e5_row11_col2, #T_e76e5_row11_col3, #T_e76e5_row12_col0, #T_e76e5_row13_col3, #T_e76e5_row13_col4 {
#   background-color: #ffffcc;
#   color: #000000;
# }
# #T_e76e5_row0_col3 {
#   background-color: #fff7b9;
#   color: #000000;
# }
# #T_e76e5_row0_col4, #T_e76e5_row9_col7 {
#   background-color: #fff6b6;
#   color: #000000;
# }
# #T_e76e5_row0_col6 {
#   background-color: #fff5b3;
#   color: #000000;
# }
# #T_e76e5_row0_col7, #T_e76e5_row3_col4 {
#   background-color: #fff4b0;
#   color: #000000;
# }
# #T_e76e5_row1_col1, #T_e76e5_row2_col4, #T_e76e5_row5_col1, #T_e76e5_row5_col5, #T_e76e5_row6_col1, #T_e76e5_row6_col5, #T_e76e5_row8_col6, #T_e76e5_row9_col4, #T_e76e5_row10_col7, #T_e76e5_row11_col1, #T_e76e5_row11_col5, #T_e76e5_row13_col6, #T_e76e5_row13_col7 {
#   background-color: #fffec9;
#   color: #000000;
# }
# #T_e76e5_row1_col4, #T_e76e5_row1_col5, #T_e76e5_row2_col3, #T_e76e5_row5_col4, #T_e76e5_row6_col4, #T_e76e5_row8_col1, #T_e76e5_row8_col4, #T_e76e5_row8_col5, #T_e76e5_row9_col2, #T_e76e5_row10_col1, #T_e76e5_row10_col5, #T_e76e5_row10_col6, #T_e76e5_row11_col4, #T_e76e5_row13_col1, #T_e76e5_row13_col2, #T_e76e5_row13_col5 {
#   background-color: #fffecb;
#   color: #000000;
# }
# #T_e76e5_row1_col6, #T_e76e5_row2_col1, #T_e76e5_row2_col5, #T_e76e5_row2_col6, #T_e76e5_row5_col6, #T_e76e5_row6_col6, #T_e76e5_row11_col6 {
#   background-color: #fffdc8;
#   color: #000000;
# }
# #T_e76e5_row1_col7, #T_e76e5_row9_col6 {
#   background-color: #fffbc2;
#   color: #000000;
# }
# #T_e76e5_row2_col7, #T_e76e5_row5_col7, #T_e76e5_row8_col7, #T_e76e5_row9_col5, #T_e76e5_row11_col7 {
#   background-color: #fffdc6;
#   color: #000000;
# }
# #T_e76e5_row3_col1, #T_e76e5_row3_col5, #T_e76e5_row12_col2 {
#   background-color: #fff2ac;
#   color: #000000;
# }
# #T_e76e5_row3_col3 {
#   background-color: #fff9be;
#   color: #000000;
# }
# #T_e76e5_row3_col6 {
#   background-color: #fff0a8;
#   color: #000000;
# }
# #T_e76e5_row3_col7 {
#   background-color: #ffe997;
#   color: #000000;
# }
# #T_e76e5_row4_col1 {
#   background-color: #fd8239;
#   color: #f1f1f1;
# }
# #T_e76e5_row4_col3 {
#   background-color: #febd57;
#   color: #000000;
# }
# #T_e76e5_row4_col4 {
#   background-color: #fd9c42;
#   color: #000000;
# }
# #T_e76e5_row4_col5 {
#   background-color: #fd883b;
#   color: #f1f1f1;
# }
# #T_e76e5_row4_col6 {
#   background-color: #fc6c33;
#   color: #f1f1f1;
# }
# #T_e76e5_row4_col7 {
#   background-color: #b00026;
#   color: #f1f1f1;
# }
# #T_e76e5_row6_col7 {
#   background-color: #fffcc4;
#   color: #000000;
# }
# #T_e76e5_row9_col1 {
#   background-color: #fffcc5;
#   color: #000000;
# }
# #T_e76e5_row12_col1 {
#   background-color: #feb24c;
#   color: #000000;
# }
# #T_e76e5_row12_col4 {
#   background-color: #fedf83;
#   color: #000000;
# }
# #T_e76e5_row12_col5 {
#   background-color: #fec05b;
#   color: #000000;
# }
# #T_e76e5_row12_col6 {
#   background-color: #fd7a37;
#   color: #f1f1f1;
# }
# </style>
# <table id="T_e76e5">
#   <thead>
#     <tr>
#       <th class="blank level0" >&nbsp;</th>
#       <th id="T_e76e5_level0_col0" class="col_heading level0 col0" >count</th>
#       <th id="T_e76e5_level0_col1" class="col_heading level0 col1" >mean</th>
#       <th id="T_e76e5_level0_col2" class="col_heading level0 col2" >std</th>
#       <th id="T_e76e5_level0_col3" class="col_heading level0 col3" >min</th>
#       <th id="T_e76e5_level0_col4" class="col_heading level0 col4" >25%</th>
#       <th id="T_e76e5_level0_col5" class="col_heading level0 col5" >50%</th>
#       <th id="T_e76e5_level0_col6" class="col_heading level0 col6" >75%</th>
#       <th id="T_e76e5_level0_col7" class="col_heading level0 col7" >max</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <th id="T_e76e5_level0_row0" class="row_heading level0 row0" >alcohol</th>
#       <td id="T_e76e5_row0_col0" class="data row0 col0" >178.00</td>
#       <td id="T_e76e5_row0_col1" class="data row0 col1" >13.00</td>
#       <td id="T_e76e5_row0_col2" class="data row0 col2" >0.81</td>
#       <td id="T_e76e5_row0_col3" class="data row0 col3" >11.03</td>
#       <td id="T_e76e5_row0_col4" class="data row0 col4" >12.36</td>
#       <td id="T_e76e5_row0_col5" class="data row0 col5" >13.05</td>
#       <td id="T_e76e5_row0_col6" class="data row0 col6" >13.68</td>
#       <td id="T_e76e5_row0_col7" class="data row0 col7" >14.83</td>
#     </tr>
#     <tr>
#       <th id="T_e76e5_level0_row1" class="row_heading level0 row1" >malic_acid</th>
#       <td id="T_e76e5_row1_col0" class="data row1 col0" >178.00</td>
#       <td id="T_e76e5_row1_col1" class="data row1 col1" >2.34</td>
#       <td id="T_e76e5_row1_col2" class="data row1 col2" >1.12</td>
#       <td id="T_e76e5_row1_col3" class="data row1 col3" >0.74</td>
#       <td id="T_e76e5_row1_col4" class="data row1 col4" >1.60</td>
#       <td id="T_e76e5_row1_col5" class="data row1 col5" >1.87</td>
#       <td id="T_e76e5_row1_col6" class="data row1 col6" >3.08</td>
#       <td id="T_e76e5_row1_col7" class="data row1 col7" >5.80</td>
#     </tr>
#     <tr>
#       <th id="T_e76e5_level0_row2" class="row_heading level0 row2" >ash</th>
#       <td id="T_e76e5_row2_col0" class="data row2 col0" >178.00</td>
#       <td id="T_e76e5_row2_col1" class="data row2 col1" >2.37</td>
#       <td id="T_e76e5_row2_col2" class="data row2 col2" >0.27</td>
#       <td id="T_e76e5_row2_col3" class="data row2 col3" >1.36</td>
#       <td id="T_e76e5_row2_col4" class="data row2 col4" >2.21</td>
#       <td id="T_e76e5_row2_col5" class="data row2 col5" >2.36</td>
#       <td id="T_e76e5_row2_col6" class="data row2 col6" >2.56</td>
#       <td id="T_e76e5_row2_col7" class="data row2 col7" >3.23</td>
#     </tr>
#     <tr>
#       <th id="T_e76e5_level0_row3" class="row_heading level0 row3" >alcalinity_of_ash</th>
#       <td id="T_e76e5_row3_col0" class="data row3 col0" >178.00</td>
#       <td id="T_e76e5_row3_col1" class="data row3 col1" >19.49</td>
#       <td id="T_e76e5_row3_col2" class="data row3 col2" >3.34</td>
#       <td id="T_e76e5_row3_col3" class="data row3 col3" >10.60</td>
#       <td id="T_e76e5_row3_col4" class="data row3 col4" >17.20</td>
#       <td id="T_e76e5_row3_col5" class="data row3 col5" >19.50</td>
#       <td id="T_e76e5_row3_col6" class="data row3 col6" >21.50</td>
#       <td id="T_e76e5_row3_col7" class="data row3 col7" >30.00</td>
#     </tr>
#     <tr>
#       <th id="T_e76e5_level0_row4" class="row_heading level0 row4" >magnesium</th>
#       <td id="T_e76e5_row4_col0" class="data row4 col0" >178.00</td>
#       <td id="T_e76e5_row4_col1" class="data row4 col1" >99.74</td>
#       <td id="T_e76e5_row4_col2" class="data row4 col2" >14.28</td>
#       <td id="T_e76e5_row4_col3" class="data row4 col3" >70.00</td>
#       <td id="T_e76e5_row4_col4" class="data row4 col4" >88.00</td>
#       <td id="T_e76e5_row4_col5" class="data row4 col5" >98.00</td>
#       <td id="T_e76e5_row4_col6" class="data row4 col6" >107.00</td>
#       <td id="T_e76e5_row4_col7" class="data row4 col7" >162.00</td>
#     </tr>
#     <tr>
#       <th id="T_e76e5_level0_row5" class="row_heading level0 row5" >total_phenols</th>
#       <td id="T_e76e5_row5_col0" class="data row5 col0" >178.00</td>
#       <td id="T_e76e5_row5_col1" class="data row5 col1" >2.30</td>
#       <td id="T_e76e5_row5_col2" class="data row5 col2" >0.63</td>
#       <td id="T_e76e5_row5_col3" class="

# %% [markdown]
# ### 3.3. Проверка на пропуски и дубликаты

# %%
print("Пропуски:")
print(df.isnull().sum().sum())
print()
print(f"Дубликаты: {df.duplicated().sum()}")
# Out:
# Пропуски:
# 0
#
# Дубликаты: 0

# %% [markdown]
# ## 4. Визуальное исследование датасета

# %% [markdown]
# ### 4.1. Распределение целевой переменной

# %%
fig, axes = plt.subplots(1, 2, figsize=(14, 5))

colors = ['#e74c3c', '#2ecc71', '#3498db']
counts = df['target_name'].value_counts()
axes[0].bar(counts.index, counts.values, color=colors, edgecolor='black', linewidth=0.8)
axes[0].set_title('Распределение классов вин', fontsize=14, fontweight='bold')
axes[0].set_xlabel('Класс вина')
axes[0].set_ylabel('Количество образцов')
for i, v in enumerate(counts.values):
    axes[0].text(i, v + 1, str(v), ha='center', fontweight='bold', fontsize=12)

axes[1].pie(counts.values, labels=counts.index, colors=colors, autopct='%1.1f%%',
            startangle=90, explode=(0.05, 0.05, 0.05), shadow=True,
            textprops={'fontsize': 12})
axes[1].set_title('Доля каждого класса', fontsize=14, fontweight='bold')

plt.tight_layout()
plt.savefig("fig_15.png", dpi=150, bbox_inches="tight")
plt.savefig('fig_1.png', dpi=150, bbox_inches='tight')
plt.show()

# %% [markdown]
# ### 4.2. Гистограммы распределений признаков

# %%
feature_cols = wine.feature_names

fig, axes = plt.subplots(4, 4, figsize=(18, 14))
axes = axes.flatten()

for i, col in enumerate(feature_cols):
    ax = axes[i]
    for cls in sorted(df['target'].unique()):
        subset = df[df['target'] == cls][col]
        ax.hist(subset, bins=15, alpha=0.6, label=wine.target_names[cls], edgecolor='black', linewidth=0.5)
    ax.set_title(col, fontsize=10, fontweight='bold')
    ax.legend(fontsize=7)

for j in range(len(feature_cols), len(axes)):
    axes[j].set_visible(False)

fig.suptitle('Распределения признаков по классам', fontsize=16, fontweight='bold', y=1.01)
plt.tight_layout()
plt.savefig("fig_17.png", dpi=150, bbox_inches="tight")
plt.savefig('fig_2.png', dpi=150, bbox_inches='tight')
plt.show()

# %% [markdown]
# ### 4.3. Ящики с усами (Box plots)

# %%
fig, axes = plt.subplots(4, 4, figsize=(18, 14))
axes = axes.flatten()

for i, col in enumerate(feature_cols):
    ax = axes[i]
    sns.boxplot(data=df, x='target_name', y=col, ax=ax, palette=colors, hue='target_name', legend=False)
    ax.set_title(col, fontsize=10, fontweight='bold')
    ax.set_xlabel('')

for j in range(len(feature_cols), len(axes)):
    axes[j].set_visible(False)

fig.suptitle('Box-plots признаков по классам', fontsize=16, fontweight='bold', y=1.01)
plt.tight_layout()
plt.savefig("fig_19.png", dpi=150, bbox_inches="tight")
plt.savefig('fig_3.png', dpi=150, bbox_inches='tight')
plt.show()

# %% [markdown]
# ### 4.4. Violin plots

# %%
fig, axes = plt.subplots(3, 3, figsize=(16, 14))
axes = axes.flatten()

selected_features = ['alcohol', 'malic_acid', 'flavanoids', 'color_intensity',
                     'hue', 'od280/od315_of_diluted_wines', 'proline',
                     'total_phenols', 'proanthocyanins']

for i, col in enumerate(selected_features):
    ax = axes[i]
    sns.violinplot(data=df, x='target_name', y=col, ax=ax, palette=colors, hue='target_name', legend=False, inner='box')
    ax.set_title(col, fontsize=11, fontweight='bold')
    ax.set_xlabel('')

fig.suptitle('Violin-plots выбранных признаков по классам', fontsize=16, fontweight='bold', y=1.01)
plt.tight_layout()
plt.savefig("fig_21.png", dpi=150, bbox_inches="tight")
plt.savefig('fig_4.png', dpi=150, bbox_inches='tight')
plt.show()

# %% [markdown]
# ### 4.5. Scatter plots (Диаграммы рассеяния)

# %%
fig, axes = plt.subplots(2, 3, figsize=(18, 10))
axes = axes.flatten()

pairs = [
    ('alcohol', 'flavanoids'),
    ('alcohol', 'color_intensity'),
    ('flavanoids', 'proline'),
    ('alcohol', 'proline'),
    ('color_intensity', 'hue'),
    ('total_phenols', 'flavanoids'),
]

for i, (x, y) in enumerate(pairs):
    ax = axes[i]
    for cls in sorted(df['target'].unique()):
        subset = df[df['target'] == cls]
        ax.scatter(subset[x], subset[y], label=wine.target_names[cls],
                   alpha=0.7, s=50, edgecolors='black', linewidth=0.5)
    ax.set_xlabel(x, fontsize=10)
    ax.set_ylabel(y, fontsize=10)
    ax.set_title(f'{x} vs {y}', fontsize=11, fontweight='bold')
    ax.legend(fontsize=8)

fig.suptitle('Диаграммы рассеяния пар признаков', fontsize=16, fontweight='bold', y=1.01)
plt.tight_layout()
plt.savefig("fig_23.png", dpi=150, bbox_inches="tight")
plt.savefig('fig_5.png', dpi=150, bbox_inches='tight')
plt.show()

# %% [markdown]
# ### 4.6. Pair plot (Матрица рассеяния)

# %%
selected = ['alcohol', 'flavanoids', 'color_intensity', 'hue', 'proline', 'target_name']
g = sns.pairplot(df[selected], hue='target_name', palette=colors,
                 diag_kind='kde', plot_kws={'alpha': 0.7, 's': 40, 'edgecolor': 'black', 'linewidth': 0.3})
g.figure.suptitle('Pair plot (5 ключевых признаков)', fontsize=16, fontweight='bold', y=1.02)
plt.savefig("fig_25.png", dpi=150, bbox_inches="tight")
plt.savefig('fig_6.png', dpi=150, bbox_inches='tight')
plt.show()

# %% [markdown]
# ## 5. Информация о корреляции признаков

# %% [markdown]
# ### 5.1. Матрица корреляций (тепловая карта)

# %%
corr_matrix = df[feature_cols].corr()

fig, ax = plt.subplots(figsize=(14, 10))
mask = np.triu(np.ones_like(corr_matrix, dtype=bool))

sns.heatmap(corr_matrix, mask=mask, annot=True, fmt='.2f', cmap='RdBu_r',
            center=0, vmin=-1, vmax=1, linewidths=0.5,
            square=True, ax=ax,
            cbar_kws={'shrink': 0.8, 'label': 'Коэффициент корреляции Пирсона'})

ax.set_title('Матрица корреляций признаков', fontsize=16, fontweight='bold', pad=20)
plt.tight_layout()
plt.savefig("fig_28.png", dpi=150, bbox_inches="tight")
plt.savefig('fig_7.png', dpi=150, bbox_inches='tight')
plt.show()

# %% [markdown]
# ### 5.2. Топ коррелированных пар

# %%
corr_pairs = []
for i in range(len(corr_matrix.columns)):
    for j in range(i+1, len(corr_matrix.columns)):
        corr_pairs.append({
            'Признак 1': corr_matrix.columns[i],
            'Признак 2': corr_matrix.columns[j],
            'Корреляция': corr_matrix.iloc[i, j]
        })

corr_df = pd.DataFrame(corr_pairs)
corr_df['|Корреляция|'] = corr_df['Корреляция'].abs()
corr_df = corr_df.sort_values('|Корреляция|', ascending=False)

corr_df.head(10).style.format({'Корреляция': '{:.3f}', '|Корреляция|': '{:.3f}'}).background_gradient(
    subset=['|Корреляция|'], cmap='YlOrRd')
# Out:
# <style type="text/css">
# #T_191e2_row0_col3 {
#   background-color: #800026;
#   color: #f1f1f1;
# }
# #T_191e2_row1_col3 {
#   background-color: #e0181d;
#   color: #f1f1f1;
# }
# #T_191e2_row2_col3 {
#   background-color: #fd913e;
#   color: #000000;
# }
# #T_191e2_row3_col3 {
#   background-color: #febd57;
#   color: #000000;
# }
# #T_191e2_row4_col3 {
#   background-color: #fec662;
#   color: #000000;
# }
# #T_191e2_row5_col3 {
#   background-color: #fedf83;
#   color: #000000;
# }
# #T_191e2_row6_col3 {
#   background-color: #fff5b5;
#   color: #000000;
# }
# #T_191e2_row7_col3 {
#   background-color: #fff7b9;
#   color: #000000;
# }
# #T_191e2_row8_col3 {
#   background-color: #fffec9;
#   color: #000000;
# }
# #T_191e2_row9_col3 {
#   background-color: #ffffcc;
#   color: #000000;
# }
# </style>
# <table id="T_191e2">
#   <thead>
#     <tr>
#       <th class="blank level0" >&nbsp;</th>
#       <th id="T_191e2_level0_col0" class="col_heading level0 col0" >Признак 1</th>
#       <th id="T_191e2_level0_col1" class="col_heading level0 col1" >Признак 2</th>
#       <th id="T_191e2_level0_col2" class="col_heading level0 col2" >Корреляция</th>
#       <th id="T_191e2_level0_col3" class="col_heading level0 col3" >|Корреляция|</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <th id="T_191e2_level0_row0" class="row_heading level0 row0" >50</th>
#       <td id="T_191e2_row0_col0" class="data row0 col0" >total_phenols</td>
#       <td id="T_191e2_row0_col1" class="data row0 col1" >flavanoids</td>
#       <td id="T_191e2_row0_col2" class="data row0 col2" >0.865</td>
#       <td id="T_191e2_row0_col3" class="data row0 col3" >0.865</td>
#     </tr>
#     <tr>
#       <th id="T_191e2_level0_row1" class="row_heading level0 row1" >61</th>
#       <td id="T_191e2_row1_col0" class="data row1 col0" >flavanoids</td>
#       <td id="T_191e2_row1_col1" class="data row1 col1" >od280/od315_of_diluted_wines</td>
#       <td id="T_191e2_row1_col2" class="data row1 col2" >0.787</td>
#       <td id="T_191e2_row1_col3" class="data row1 col3" >0.787</td>
#     </tr>
#     <tr>
#       <th id="T_191e2_level0_row2" class="row_heading level0 row2" >55</th>
#       <td id="T_191e2_row2_col0" class="data row2 col0" >total_phenols</td>
#       <td id="T_191e2_row2_col1" class="data row2 col1" >od280/od315_of_diluted_wines</td>
#       <td id="T_191e2_row2_col2" class="data row2 col2" >0.700</td>
#       <td id="T_191e2_row2_col3" class="data row2 col3" >0.700</td>
#     </tr>
#     <tr>
#       <th id="T_191e2_level0_row3" class="row_heading level0 row3" >58</th>
#       <td id="T_191e2_row3_col0" class="data row3 col0" >flavanoids</td>
#       <td id="T_191e2_row3_col1" class="data row3 col1" >proanthocyanins</td>
#       <td id="T_191e2_row3_col2" class="data row3 col2" >0.653</td>
#       <td id="T_191e2_row3_col3" class="data row3 col3" >0.653</td>
#     </tr>
#     <tr>
#       <th id="T_191e2_level0_row4" class="row_heading level0 row4" >11</th>
#       <td id="T_191e2_row4_col0" class="data row4 col0" >alcohol</td>
#       <td id="T_191e2_row4_col1" class="data row4 col1" >proline</td>
#       <td id="T_191e2_row4_col2" class="data row4 col2" >0.644</td>
#       <td id="T_191e2_row4_col3" class="data row4 col3" >0.644</td>
#     </tr>
#     <tr>
#       <th id="T_191e2_level0_row5" class="row_heading level0 row5" >52</th>
#       <td id="T_191e2_row5_col0" class="data row5 col0" >total_phenols</td>
#       <td id="T_191e2_row5_col1" class="data row5 col1" >proanthocyanins</td>
#       <td id="T_191e2_row5_col2" class="data row5 col2" >0.612</td>
#       <td id="T_191e2_row5_col3" class="data row5 col3" >0.612</td>
#     </tr>
#     <tr>
#       <th id="T_191e2_level0_row6" class="row_heading level0 row6" >75</th>
#       <td id="T_191e2_row6_col0" class="data row6 col0" >hue</td>
#       <td id="T_191e2_row6_col1" class="data row6 col1" >od280/od315_of_diluted_wines</td>
#       <td id="T_191e2_row6_col2" class="data row6 col2" >0.565</td>
#       <td id="T_191e2_row6_col3" class="data row6 col3" >0.565</td>
#     </tr>
#     <tr>
#       <th id="T_191e2_level0_row7" class="row_heading level0 row7" >20</th>
#       <td id="T_191e2_row7_col0" class="data row7 col0" >malic_acid</td>
#       <td id="T_191e2_row7_col1" class="data row7 col1" >hue</td>
#       <td id="T_191e2_row7_col2" class="data row7 col2" >-0.561</td>
#       <td id="T_191e2_row7_col3" class="data row7 col3" >0.561</td>
#     </tr>
#     <tr>
#       <th id="T_191e2_level0_row8" class="row_heading level0 row8" >8</th>
#       <td id="T_191e2_row8_col0" class="data row8 col0" >alcohol</td>
#       <td id="T_191e2_row8_col1" class="data row8 col1" >color_intensity</td>
#       <td id="T_191e2_row8_col2" class="data row8 col2" >0.546</td>
#       <td id="T_191e2_row8_col3" class="data row8 col3" >0.546</td>
#     </tr>
#     <tr>
#       <th id="T_191e2_level0_row9" class="row_heading level0 row9" >60</th>
#       <td id="T_191e2_row9_col0" class="data row9 col0" >flavanoids</td>
#       <td id="T_191e2_row9_col1" class="data row9 col1" >hue</td>
#       <td id="T_191e2_row9_col2" class="data row9 col2" >0.543</td>
#       <td id="T_191e2_row9_col3" class="data row9 col3" >0.543</td>
#     </tr>
#   </tbody>
# </table>

# %% [markdown]
# ### 5.3. Корреляция признаков с целевой переменной

# %%
target_corr = df[feature_cols].corrwith(df['target']).sort_values(ascending=True)

fig, ax = plt.subplots(figsize=(10, 8))

colors_bar = ['#e74c3c' if v < 0 else '#2ecc71' for v in target_corr.values]
bars = ax.barh(target_corr.index, target_corr.values, color=colors_bar, edgecolor='black', linewidth=0.5)

ax.set_xlabel('Коэффициент корреляции Пирсона', fontsize=12)
ax.set_title('Корреляция признаков с целевой переменной', fontsize=14, fontweight='bold')
ax.axvline(x=0, color='black', linewidth=0.8)

for bar, val in zip(bars, target_corr.values):
    ax.text(val + (0.01 if val >= 0 else -0.01), bar.get_y() + bar.get_height()/2,
            f'{val:.2f}', va='center', ha='left' if val >= 0 else 'right', fontsize=9)

plt.tight_layout()
plt.savefig("fig_32.png", dpi=150, bbox_inches="tight")
plt.savefig('fig_8.png', dpi=150, bbox_inches='tight')
plt.show()

# %% [markdown]
# ### 5.4. Scatter plots сильно коррелированных пар

# %%
top_pairs = corr_df.head(4)

fig, axes = plt.subplots(1, 4, figsize=(20, 5))

for idx, (_, row) in enumerate(top_pairs.iterrows()):
    ax = axes[idx]
    feat1, feat2, corr = row['Признак 1'], row['Признак 2'], row['Корреляция']
    
    for cls in sorted(df['target'].unique()):
        subset = df[df['target'] == cls]
        ax.scatter(subset[feat1], subset[feat2], label=wine.target_names[cls],
                   alpha=0.7, s=50, edgecolors='black', linewidth=0.5)
    
    ax.set_xlabel(feat1, fontsize=9)
    ax.set_ylabel(feat2, fontsize=9)
    ax.set_title(f'r = {corr:.2f}', fontsize=11, fontweight='bold')
    ax.legend(fontsize=7)

fig.suptitle('Диаграммы рассеяния наиболее коррелированных пар', fontsize=14, fontweight='bold', y=1.02)
plt.tight_layout()
plt.savefig("fig_34.png", dpi=150, bbox_inches="tight")
plt.savefig('fig_9.png', dpi=150, bbox_inches='tight')
plt.show()

# %% [markdown]
# ## 6. Выводы
#
# 1. **Размер и качество данных:** Датасет Wine содержит 178 наблюдений и 13 числовых признаков. Пропуски и дубликаты отсутствуют.
#
# 2. **Распределение классов:** Три класса вин представлены относительно сбалансированно (59, 71 и 48 образцов).
#
# 3. **Распределение признаков:** Большинство признаков имеют различные распределения для разных классов, что говорит о их информативности для классификации.
#
# 4. **Корреляция:**
#    - Сильная положительная корреляция наблюдается между `total_phenols` и `flavanoids`.
#    - Сильная отрицательная корреляция — между `hue` и `color_intensity`.
#    - Признаки `flavanoids`, `proline`, `color_intensity`, `alcohol` имеют наибольшую корреляцию с целевой переменной.
#
# 5. **Визуализация** позволяет визуально подтвердить разделимость классов по многим признакам, что является хорошим знаком для дальнейшей классификации.
